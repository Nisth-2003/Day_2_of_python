# %%
#swap two numbers
a=int(input("Enter a:"))
b=int(input("Enter b:"))
temp=a
a=b
b=temp
print("a=",a)
print("b=",b)
# Out:
# Enter a:5
# Enter b:4
# a= 4
# b= 5

# %%
import random as r
print(r.randint(0,9))
# Out:
# 4

# %%
#km to miles(1km =0.621)
a=int(input("enter km:"))
print(a*0.621)
# Out:
# enter km:2
# 1.242

# %%
#celsius to fahrenheit
a=int(input("Enter celsius:"))
f=(a*9/5)+32
print(f)
# Out:
# Enter celsius:1
# 33.8
